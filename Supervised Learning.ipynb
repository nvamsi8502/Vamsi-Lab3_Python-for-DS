# %% [markdown]
# **Q1** Importing Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 2. Load the dataset and display a sample of five rows of the data frame.

# %%
df = pd.read_csv("C:/Users/Testbook/Downloads/heart_2020_cleaned.csv")

# %%
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %% [markdown]
# 3. Check the shape of the data (number of rows and columns). Check the general information about the dataframe using the .info() method.

# %%
df.shape
# Out:
# (319795, 18)

# %%
df.info
# Out:
# <bound method DataFrame.info of        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
# ...

# %% [markdown]
# 4. Check the statistical summary of the dataset and write your inferences.

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %%
data_types = df.dtypes

print(data_types)
# Out:
# HeartDisease         object
# BMI                 float64
# Smoking              object
# AlcoholDrinking      object
# Stroke               object
# PhysicalHealth      float64
# MentalHealth        float64
# DiffWalking          object
# Sex                  object
# AgeCategory          object
# Race                 object
# Diabetic             object
# PhysicalActivity     object
# GenHealth            object
# SleepTime           float64
# Asthma               object
# KidneyDisease        object
# SkinCancer           object
# dtype: object

# %%
missing_value = df.isnull().sum()
print(missing_value)
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
total_rows = len(df)
print(total_rows)
# Out:
# 319795

# %% [markdown]
#  5. Check the percentage of missing values in each column of the data frame. Drop the missing values if there are any.

# %%
Percentage_missing_values = (missing_value / total_rows)*100
print(Percentage_missing_values)
# Out:
# HeartDisease        0.0
# BMI                 0.0
# Smoking             0.0
# AlcoholDrinking     0.0
# Stroke              0.0
# PhysicalHealth      0.0
# MentalHealth        0.0
# DiffWalking         0.0
# Sex                 0.0
# AgeCategory         0.0
# Race                0.0
# Diabetic            0.0
# PhysicalActivity    0.0
# GenHealth           0.0
# SleepTime           0.0
# Asthma              0.0
# KidneyDisease       0.0
# SkinCancer          0.0
# dtype: float64

# %%
6. Check if there are any duplicate rows. If any drop them and check the shape of the dataframe after dropping duplicates.

# %%
duplicates = df.duplicated()
print(duplicates)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 319790    False
# 319791    False
# 319792    False
# 319793    False
# 319794    False
# Length: 319795, dtype: bool

# %%
print(df.shape)
# Out:
# (319795, 18)

# %% [markdown]
# Checking the distribution of the target variable (in this case, HeartDisease) means analyzing how the values of this variable are spread across the dataset. This involves understanding the frequency or proportion of each category within the target variable.
#
# Why We Do It:
# Class Imbalance: To identify if there is a class imbalance, which occurs when one class is significantly more frequent than the other(s). This can affect the performance of classification models.
# Model Selection and Evaluation: Understanding the distribution helps in choosing appropriate metrics and models. For example, precision, recall, and F1-score might be more informative than accuracy in the case of imbalanced classes.
# Data Insights: To gain insights into the dataset. For example, if HeartDisease is a binary variable (Yes/No), knowing the proportion of patients with and without heart disease provides a baseline understanding of the data.
# Steps to Check the Distribution:
# Load the Dataset: Load your dataset into a pandas DataFrame.
# Calculate Distribution: Calculate the frequency or proportion of each unique value in the HeartDisease column.
# Visualize the Distribution: Use visual tools like bar plots or pie charts to visualize the distribution.

# %% [markdown]
# 7. Check the distribution of the target variable (i.e. 'HeartDisease') and write your observations.

# %%
heart_disease_distribution = df['HeartDisease'].value_counts()

print(heart_disease_distribution)
# Out:
# HeartDisease
# No     292422
# Yes     27373
# Name: count, dtype: int64

# %% [markdown]
# 8. Visualize the distribution of the target column 'Heart disease' with respect to various categorical features and write your observations.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv("C:/Users/Testbook/Downloads/heart_2020_cleaned.csv")
# List of categorical features
categorical_features = ['Smoking', 'AlcoholDrinking', 'Stroke', 'DiffWalking', 'Sex', 'AgeCategory', 'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'Asthma', 'KidneyDisease', 'SkinCancer']

# Plot the distribution of HeartDisease with respect to each categorical feature
for feature in categorical_features:
    plt.figure(figsize=(10, 5))
    sns.countplot(data=df, x=feature, hue='HeartDisease')
    plt.title(f'Distribution of HeartDisease with respect to {feature}')
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.legend(title='HeartDisease', loc='upper right')
    plt.show()

# %% [markdown]
#  9. Check the unique categories in the column 'Diabetic'. Replace 'Yes (during pregnancy)' as 'Yes' and 'No, borderline diabetes' as 'No'.

# %%
df['Diabetic'] = df['Diabetic'].replace({'Yes (during pregnancy)': 'Yes', 'No, borderline diabetes': 'No'})
unique_categories = df['Diabetic'].unique()
print(unique_categories)
# Out:
# ['Yes' 'No']

# %% [markdown]
#  10. For the target column 'HeartDiease', Replace 'No' as 0 and 'Yes' as 1.

# %%
df['HeartDisease'] = df['HeartDisease'].replace({'No': 0, 'Yes': 1})
unique_categories = df['HeartDisease'].unique()
print(unique_categories)
# Out:
# [0 1]

# %% [markdown]
# 11. Label Encode the columns "AgeCategory", "Race", and "GenHealth". Encode the rest of the columns using dummy encoding approach.

# %%
##Q11 solution
from sklearn import preprocessing

object_type_variable=[i for i in df[['AgeCategory','Race','GenHealth']] if df.dtypes[i]==object]
object_type_variable

le=preprocessing.LabelEncoder()

def encoder(df):
    for i in object_type_variable:
        q=le.fit_transform(df[i].astype(str))
        df[i]=q
        df[i]=df[i].astype(int)
encoder(df)

# %%
df=pd.get_dummies(df,drop_first=True)

# %%
df.head(2)
# Out:
#    HeartDisease    BMI  PhysicalHealth  MentalHealth  AgeCategory  Race  \
# 0             0  16.60             3.0          30.0            7     5
# 1             0  20.34             0.0           0.0           12     5
#
#    GenHealth  SleepTime  Smoking_Yes  AlcoholDrinking_Yes  Stroke_Yes  \
# 0          4        5.0         True                False       False
# 1          4        7.0        False                False        True
#
#    DiffWalking_Yes  Sex_Male  Diabetic_Yes  PhysicalActivity_Yes  Asthma_Yes  \
# 0            False     False          True                  True        True
# 1            False     False         False                  True       False
#
#    KidneyDisease_Yes  SkinCancer_Yes
# 0              False            True
# 1              False           False

# %%
##q11 solution
encoder=preprocessing.LabelEncoder() ##AgeCategory
df['AgeCategory']=encoder.fit_transform(df['AgeCategory'])
df['AgeCategory'].unique()
# Out:
# array([ 7, 12,  9, 11,  4, 10,  8,  6,  5,  0,  3,  2,  1], dtype=int64)

# %%
##q11 solution
df['Race']=encoder.fit_transform(df['Race']) ##Race
df['Race'].unique()
# Out:
# array([5, 2, 1, 0, 4, 3], dtype=int64)

# %%
##q11 solution
df['GenHealth']=encoder.fit_transform(df['GenHealth']) ##GenHealth
df['GenHealth'].unique()
# Out:
# array([4, 1, 2, 3, 0], dtype=int64)

# %% [markdown]
#  12. Store the target column (i.e.'HeartDisease') in the y variable and the rest of the columns in the X variable.

# %%
##q12 solution
data=pd.read_csv("C:/Users/Testbook/Downloads/heart_2020_cleaned.csv")
x=data.drop(['HeartDisease'],axis=1).values
y=data['HeartDisease'].values
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0)

# %% [markdown]
# 13. Split the dataset into two parts (i.e. 70% train and 30% test) and print the shape of the train and test data

# %%
from sklearn.model_selection import train_test_split

# %%
##q13 solution
data1=pd.read_csv("C:/Users/Testbook/Downloads/heart_2020_cleaned.csv")
x=data1.drop(['HeartDisease'],axis=1).values
y=data1['HeartDisease'].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
print(x_train.shape,x_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (255836, 17) (63959, 17)
# (255836,) (63959,)

# %% [markdown]
# 14. Standardize the numerical columns using Standard Scalar approach for both train and test data.

# %%
from sklearn.preprocessing import StandardScaler
##q14 solution
ss=StandardScaler()
x_train.iloc[:,:7]=ss.fit_transform(x_train.iloc[:,:7])
x_test.iloc[:,:7]=ss.fit_transform(x_test.iloc[:,:7])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 4
#       2 ##q14 solution
#       3 ss=StandardScaler()
# ----> 4 x_train.iloc[:,:7]=ss.fit_transform(x_train.iloc[:,:7])
#       5 x_test.iloc[:,:7]=ss.fit_transform(x_test.iloc[:,:7])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iloc'

# %%
X_train.head(2)
# Out:
#        AgeCategory      Race  GenHealth  BMI_12.02  BMI_12.08  BMI_12.13  \
# 61758     1.257009 -2.801526   0.507284  -0.002796  -0.001977  -0.001977
# 9963     -0.705813  0.497973  -1.447356  -0.002796  -0.001977  -0.001977
#
#        BMI_12.16  BMI_12.2  BMI_12.21  BMI_12.26  ...  SleepTime_21.0  \
# 61758  -0.001977     False      False      False  ...           False
# 9963   -0.001977     False      False      False  ...           False
#
#        SleepTime_22.0  SleepTime_23.0  SleepTime_24.0  Asthma_No  Asthma_Yes  \
# 61758           False           False           False      False        True
# 9963            False           False           False       True       False
#
#        KidneyDisease_No  KidneyDisease_Yes  SkinCancer_No  SkinCancer_Yes
# 61758             False               True           True           False
# 9963               True              False           True           False
#
# [2 rows x 3713 columns]

# %%
X_test.head(2)
# Out:
#         AgeCategory      Race  GenHealth  BMI_12.02  BMI_12.08  BMI_12.13  \
# 140046     0.696203  0.497973   1.158831  -0.002796  -0.001977  -0.001977
# 18160     -1.266619 -0.326902   1.158831  -0.002796  -0.001977  -0.001977
#
#         BMI_12.16  BMI_12.2  BMI_12.21  BMI_12.26  ...  SleepTime_21.0  \
# 140046  -0.001977     False      False      False  ...           False
# 18160   -0.001977     False      False      False  ...           False
#
#         SleepTime_22.0  SleepTime_23.0  SleepTime_24.0  Asthma_No  Asthma_Yes  \
# 140046           False           False           False       True       False
# 18160            False           False           False       True       False
#
#         KidneyDisease_No  KidneyDisease_Yes  SkinCancer_No  SkinCancer_Yes
# 140046              True              False          False            True
# 18160               True              False           True           False
#
# [2 rows x 3713 columns]

# %% [markdown]
# 15. Write a function.¶

# %%
def fit_n_print(model, X_train, X_test, y_train, y_test):  # take the model, and data as inputs

    model.fit(X_train, y_train)   # fits the model with the train data

    pred = model.predict(X_test)  # makes predictions on the test set

    accuracy = accuracy_score(y_test, pred)
                   
    return accuracy  # return all the metrics

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, StackingClassifier
from sklearn.preprocessing import StandardScaler

# Initialize the models with adjusted Logistic Regression
lr = LogisticRegression(max_iter=1000)
nb = GaussianNB()
knn = KNeighborsClassifier()
dt = DecisionTreeClassifier()
rf = RandomForestClassifier()
adb = AdaBoostClassifier()
gb = GradientBoostingClassifier()

# Set up the estimators for stacking
estimators = [('rf', rf), ('knn', knn), ('gb', gb), ('adb', adb)]
sc = StackingClassifier(estimators=estimators, final_estimator=rf)

# Assuming X_train, X_test, y_train, y_test are already defined
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

result = pd.DataFrame(columns=['Accuracy'])

# Define fit_n_print function
def fit_n_print(model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    return accuracy

for model, model_name in zip([lr, nb, knn, dt, rf, adb, gb, sc], 
                             ['Logistic Regression','Naive Bayes','KNN','Decision tree', 
                              'Random Forest', 'Ada Boost', 'Gradient Boost', 'Stacking']):
    
    result.loc[model_name] = fit_n_print(model, X_train_scaled, X_test_scaled, y_train, y_test)

print(result)
# Out:
#                      Accuracy
# Logistic Regression    0.8985
# Naive Bayes            0.1910
# KNN                    0.9015
# Decision tree          0.8925
# Random Forest          0.8950
# Ada Boost              0.9005
# Gradient Boost         0.9025
# Stacking               0.9015
